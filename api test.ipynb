# %%
import requests, json, matplotlib.pyplot as plt

# %%
url = 'http://127.0.0.1:8000/api/calculate/'

# %%
data = json.dumps({
    "expectedeChargingEnergy":1000,
    "epochs":10
})

resp = requests.post(url, data=data)
resp
# Out:
# <Response [200]>

# %%
response = resp.json()

parsedResponse = json.loads(response)

plt.plot(parsedResponse['OOF']); plt.plot(parsedResponse['OOF'])

# %%
parsedResponse['computation_time'], parsedResponse['Error']
# Out:
# (215.03090834617615, 0.4974558116438409)
